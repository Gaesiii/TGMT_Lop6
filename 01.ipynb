# %%
# ctrl + enter: runcode 
#shift + enter : Run code => them mot dong moi
#Import thu vien
from PIL import Image

# %%
#thu muc chua hinh anh
dir = 'C:/Users/L7pho/anhtest'

# %%
image_path = dir + '/test1.jpg'
print (image_path)
# Out:
# C:/Users/L7pho/anhtest/test1.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x410>

# %%
print ("Dinh Dang Anh : " , img01.format)
# Out:
# Dinh Dang Anh :  JPEG

# %%
#in size
print ("kich thuoc hinh anh : ", img01.size)
# Out:
# kich thuoc hinh anh :  (728, 410)

# %%
#luu va chuyen doi dang anh
new_img_01_path = dir + '/new_01.jpg'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
#close
img01.close()

# %%
git init
# Out:
#   Cell In[35], line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\L7pho\TGMT_Lop6
